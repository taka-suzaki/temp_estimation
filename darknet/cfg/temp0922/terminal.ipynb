# %%
# !unzip datasets.zip
# Out:
# Archive:  datasets.zip
#    creating: datasets/
#   inflating: datasets/1598605729.txt
#   inflating: datasets/1598606220.txt
#   inflating: datasets/1598609675.txt
#   inflating: datasets/1598603070.jpg
#   inflating: datasets/1598606234.txt
#   inflating: datasets/1598607102.txt
#   inflating: datasets/1598609575.jpg
#   inflating: datasets/1598607664.txt
#   inflating: datasets/1598609561.jpg
#   inflating: datasets/1598606652.jpg
#   inflating: datasets/1598610030.jpg
#   inflating: datasets/1598607116.txt
#   inflating: datasets/1598605098.txt
#   inflating: datasets/1598608858.jpg
#   inflating: datasets/1598610495.txt
#   inflating: datasets/1598606691.jpg
#   inflating: datasets/1598608864.jpg
#   inflating: datasets/1598608455.jpg
#   inflating: datasets/1598607766.jpg
#   inflating: datasets/1598610126.txt
#   inflating: datasets/1598608769.txt
#   inflating: datasets/1598609477.txt
#   inflating: datasets/1598610640.txt
#   inflating: datasets/1598608333.jpg
# ...
